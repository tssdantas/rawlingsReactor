# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = []
with open('output_stiff_benzeno.csv','r') as f:
    #lines = f.readlines()
    while line := f.readline():
        currentline = line.rstrip().split(",")
        data.append(currentline[:5])

# %%
df = pd.DataFrame(data, columns=['x', 'y1', 'y2', 'y3', 'y4'])

# %%
df.head()
# Out:
#                     x                   y1                   y2  \
# 0                 0.0                  1.0                  0.0
# 1  1.5015015015015014   0.4133349239324092  0.33903919222886725
# 2   3.003003003003003  0.41333492393263516  0.33903919222861423
# 3   4.504504504504505  0.41333492393263854   0.3390391922286104
# 4   6.006006006006006    0.413334923932642   0.3390391922286065
#
#                     y3                   y4
# 0                  0.0                  0.0
# 1  0.15621257544858164   0.0914133083901427
# 2    0.156212575448889  0.09141330838986253
# 3  0.15621257544889366  0.09141330838985827
# 4  0.15621257544889833  0.09141330838985402

# %%
fig = px.line(df, x='x', y=['y1', 'y2', 'y3', 'y4'])
fig.update_yaxes(autorange="reversed")
fig.show()

# %%
# plt.figure(figsize=(10, 6))
# for col in df.columns[1:]:  # Skip the first column ('x')
#     plt.plot(df['x'], df[col], label=col)

# plt.xlabel('x')
# plt.ylabel('Values')
# plt.title('Line Plot of DataFrame Columns')
# plt.legend()
# plt.grid(True)
# plt.show()
